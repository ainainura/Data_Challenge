# %% [markdown]
# ## Analysis of the dataset US census
#
# This is a simplified dataset released by the American Community Survey (part of the US Census) showing detailed estimates of the age and sex breakdown of the population by ZCTA (ZIP code tabulation area), a rough equivalent of zip code.
#
# Unless the column is titled "Total," the population estimates are percentages.

# %%
import pandas as pd

# loading dataset from file into dataframe
census_data = pd.read_csv("acs_population_demographics.csv")
print(census_data.head())
print(census_data.shape)
# Out:
#    ZIP  Total; Estimate; Total population  Male; Estimate; Total population  \
# 0  601                              18088                              8824
# 1  602                              40859                             20079
# 2  603                              53162                             25971
# 3  606                               6415                              3188
# 4  610                              28805                             13958
#
#    Female; Estimate; Total population  Total; Estimate; AGE - Under 5 years  \
# 0                                9264                                   5.8
# 1                               20780                                   5.2
# 2                               27191                                   5.3
# 3                                3227                                   5.7
# 4                               14847                                   5.2
#
#    Male; Estimate; AGE - Under 5 years  Female; Estimate; AGE - Under 5 years  \
# 0                                  5.9                                    5.6
# 1                                  5.4                                    5.0
# 2                                  5.6                                    5.0
# 3                                  8.5                                    2.9
# 4                                  5.4                                    5.1
#
#    Total; Estimate; AGE - 5 to 9 years  Male; Estimate; AGE - 5 to 9 years  \
# 0                                  6.3                                 6.6
# 1                                  6.2                                 6.4
# 2                                  6.4                                 6.8
# 3                                  5.8                                 6.2
# 4                                  5.4                                 5.4
#
#    Female; Estimate; AGE - 5 to 9 years  \
# 0                                   6.1
# 1                                   6.1
# 2                                   6.0
# 3                                   5.4
# 4                                   5.4
#
#                                ...                               \
# 0                              ...
# 1                              ...
# 2                              ...
# 3                              ...
# 4                              ...
#
#    Total; Estimate; AGE - 85 years and over  \
# 0                                       1.8
# 1                                       1.5
# 2                                       1.3
# 3                                       2.6
# 4                                       1.5
#
#    Male; Estimate; AGE - 85 years and over  \
# 0                                      1.5
# 1                                      1.1
# 2                                      0.7
# 3                                      2.5
# 4                                      1.5
#
#    Female; Estimate; AGE - 85 years and over  \
# 0                                        2.1
# 1                                        1.9
# 2                                        1.8
# 3                                        2.7
# 4                                        1.5
#
#    Total; Estimate; SUMMARY INDICATORS - Median age (years)  \
# 0                                               37.1
# 1                                               39.0
# 2                                               39.2
# 3                                               39.2
# 4                                               39.7
#
#    Male; Estimate; SUMMARY INDICATORS - Median age (years)  \
# 0                                               36.2
# 1                                               38.5
# 2                                               37.4
# 3                                               37.7
# 4                                               36.8
#
#    Female; Estimate; SUMMARY INDICATORS - Median age (years)  \
# 0                                               38.9
# 1                                               39.7
# 2                                               40.8
# 3                                               39.6
# 4                                               41.3
#
#    Total; Estimate; SUMMARY INDICATORS - Sex ratio (males per 100 females)  \
# 0                                               95.3
# 1                                               96.6
# 2                                               95.5
# 3                                               98.8
# 4                                               94.0
#
#    Total; Estimate; SUMMARY INDICATORS - Age dependency ratio  \
# 0                                               63.8
# 1                                               56.5
# 2                                               64.4
# 3                                               62.9
# 4                                               62.5
#
#    Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio  \
# 0                                               24.2
# 1                                               21.9
# 2                                               28.0
# 3                                               24.6
# 4                                               26.0
#
#    Total; Estimate; SUMMARY INDICATORS - Child dependency ratio
# 0                                               39.7
# 1                                               34.6
# 2                                               36.5
# 3                                               38.4
# 4                                               36.6
#
# [5 rows x 65 columns]
# (33120, 65)

# %% [markdown]
# There are 65 columns in this data and 33120 rows.

# %%
# let's get some statistics for each column
census_data.describe(include='all')
# Out:
#                 ZIP  Total; Estimate; Total population  \
# count  33120.000000                       33120.000000
# mean   49666.334209                        9593.274607
# std    27564.925769                       14090.093299
# min      601.000000                           0.000000
# 25%    26634.750000                         717.000000
# 50%    49739.000000                        2805.500000
# 75%    72123.500000                       13066.000000
# max    99929.000000                      115013.000000
#
#        Male; Estimate; Total population  Female; Estimate; Total population  \
# count                      33120.000000                        33120.000000
# mean                        4717.528986                         4875.745622
# std                         6893.986382                         7215.787887
# min                            0.000000                            0.000000
# 25%                          363.000000                          349.750000
# 50%                         1405.000000                         1386.000000
# 75%                         6448.000000                         6613.000000
# max                        59208.000000                        59173.000000
#
#        Total; Estimate; AGE - Under 5 years  \
# count                          32814.000000
# mean                               5.602965
# std                                3.352056
# min                                0.000000
# 25%                                3.800000
# 50%                                5.600000
# 75%                                7.200000
# max                               50.000000
#
#        Male; Estimate; AGE - Under 5 years  \
# count                         32764.000000
# mean                              5.750769
# std                               4.235060
# min                               0.000000
# 25%                               3.400000
# 50%                               5.600000
# 75%                               7.600000
# max                             100.000000
#
#        Female; Estimate; AGE - Under 5 years  \
# count                           32720.000000
# mean                                5.457210
# std                                 4.060242
# min                                 0.000000
# 25%                                 3.200000
# 50%                                 5.300000
# 75%                                 7.100000
# max                                87.100000
#
#        Total; Estimate; AGE - 5 to 9 years  \
# count                         32814.000000
# mean                              5.974322
# std                               3.317577
# min                               0.000000
# 25%                               4.300000
# 50%                               6.000000
# 75%                               7.500000
# max                              68.800000
#
#        Male; Estimate; AGE - 5 to 9 years  \
# count                        32764.000000
# mean                             6.074698
# std                              4.080002
# min                              0.000000
# 25%                              3.900000
# 50%                              6.100000
# 75%                              7.900000
# max                            100.000000
#
#        Female; Estimate; AGE - 5 to 9 years  \
# count                          32720.000000
# mean                               5.859795
# std                                4.136502
# min                                0.000000
# 25%                                3.700000
# 50%                                5.700000
# 75%                                7.600000
# max                              100.000000
#
#                                    ...                               \
# count                              ...
# mean                               ...
# std                                ...
# min                                ...
# 25%                                ...
# 50%                                ...
# 75%                                ...
# max                                ...
#
#        Total; Estimate; AGE - 85 years and over  \
# count                              32814.000000
# mean                                   2.026175
# std                                    2.672900
# min                                    0.000000
# 25%                                    0.800000
# 50%                                    1.600000
# 75%                                    2.600000
# max                                   96.400000
#
#        Male; Estimate; AGE - 85 years and over  \
# count                             32764.000000
# mean                                  1.449802
# std                                   2.702529
# min                                   0.000000
# 25%                                   0.200000
# 50%                                   1.000000
# 75%                                   1.800000
# max                                 100.000000
#
#        Female; Estimate; AGE - 85 years and over  \
# count                               32720.000000
# mean                                    2.580562
# std                                     3.534591
# min                                     0.000000
# 25%                                     0.800000
# 50%                                     2.000000
# 75%                                     3.400000
# max                                   100.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32614.000000
# mean                                           41.703983
# std                                             8.596534
# min                                             5.900000
# 25%                                            36.400000
# 50%                                            41.400000
# 75%                                            46.300000
# max                                            91.800000
#
#        Male; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32306.000000
# mean                                           40.683585
# std                                             8.936146
# min                                             2.900000
# 25%                                            35.100000
# 50%                                            40.200000
# 75%                                            45.600000
# max                                            87.100000
#
#        Female; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32276.000000
# mean                                           42.451701
# std                                             8.843847
# min                                             1.900000
# 25%                                            37.200000
# 50%                                            42.400000
# 75%                                            47.400000
# max                                            94.300000
#
#        Total; Estimate; SUMMARY INDICATORS - Sex ratio (males per 100 females)  \
# count                                       32670.000000
# mean                                          110.123153
# std                                           284.703561
# min                                             1.900000
# 25%                                            91.325000
# 50%                                            98.300000
# 75%                                           107.700000
# max                                         31725.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Age dependency ratio  \
# count                                       32457.000000
# mean                                           67.838220
# std                                            56.738616
# min                                             0.000000
# 25%                                            55.300000
# 50%                                            63.900000
# 75%                                            74.200000
# max                                          6600.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio  \
# count                                       32053.000000
# mean                                           31.081484
# std                                            55.975705
# min                                             0.000000
# 25%                                            19.000000
# 50%                                            25.500000
# 75%                                            34.000000
# max                                          6600.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Child dependency ratio
# count                                       31796.000000
# mean                                           37.915804
# std                                            15.970163
# min                                             0.000000
# 25%                                            30.300000
# 50%                                            37.100000
# 75%                                            44.100000
# max                                           528.600000
#
# [8 rows x 65 columns]

# %%
# There are missing values in this dataset, and also we have 0s for some columns which doesn't make sense,
# therefore those are also missing values. 
census_data.isnull().values.any()
# Out:
# True

# %%
# this will print the number of missing values in each column, but this doesn't consider 0s. 
census_data.isnull().sum()
# Out:
# ZIP                                                                           0
# Total; Estimate; Total population                                             0
# Male; Estimate; Total population                                              0
# Female; Estimate; Total population                                            0
# Total; Estimate; AGE - Under 5 years                                        306
# Male; Estimate; AGE - Under 5 years                                         356
# Female; Estimate; AGE - Under 5 years                                       400
# Total; Estimate; AGE - 5 to 9 years                                         306
# Male; Estimate; AGE - 5 to 9 years                                          356
# Female; Estimate; AGE - 5 to 9 years                                        400
# Total; Estimate; AGE - 10 to 14 years                                       306
# Male; Estimate; AGE - 10 to 14 years                                        356
# Female; Estimate; AGE - 10 to 14 years                                      400
# Total; Estimate; AGE - 15 to 19 years                                       306
# Male; Estimate; AGE - 15 to 19 years                                        356
# Female; Estimate; AGE - 15 to 19 years                                      400
# Total; Estimate; AGE - 20 to 24 years                                       306
# Male; Estimate; AGE - 20 to 24 years                                        356
# Female; Estimate; AGE - 20 to 24 years                                      400
# Total; Estimate; AGE - 25 to 29 years                                       306
# Male; Estimate; AGE - 25 to 29 years                                        356
# Female; Estimate; AGE - 25 to 29 years                                      400
# Total; Estimate; AGE - 30 to 34 years                                       306
# Male; Estimate; AGE - 30 to 34 years                                        356
# Female; Estimate; AGE - 30 to 34 years                                      400
# Total; Estimate; AGE - 35 to 39 years                                       306
# Male; Estimate; AGE - 35 to 39 years                                        356
# Female; Estimate; AGE - 35 to 39 years                                      400
# Total; Estimate; AGE - 40 to 44 years                                       306
# Male; Estimate; AGE - 40 to 44 years                                        356
#                                                                            ...
# Male; Estimate; AGE - 50 to 54 years                                        356
# Female; Estimate; AGE - 50 to 54 years                                      400
# Total; Estimate; AGE - 55 to 59 years                                       306
# Male; Estimate; AGE - 55 to 59 years                                        356
# Female; Estimate; AGE - 55 to 59 years                                      400
# Total; Estimate; AGE - 60 to 64 years                                       306
# Male; Estimate; AGE - 60 to 64 years                                        356
# Female; Estimate; AGE - 60 to 64 years                                      400
# Total; Estimate; AGE - 65 to 69 years                                       306
# Male; Estimate; AGE - 65 to 69 years                                        356
# Female; Estimate; AGE - 65 to 69 years                                      400
# Total; Estimate; AGE - 70 to 74 years                                       306
# Male; Estimate; AGE - 70 to 74 years                                        356
# Female; Estimate; AGE - 70 to 74 years                                      400
# Total; Estimate; AGE - 75 to 79 years                                       306
# Male; Estimate; AGE - 75 to 79 years                                        356
# Female; Estimate; AGE - 75 to 79 years                                      400
# Total; Estimate; AGE - 80 to 84 years                                       306
# Male; Estimate; AGE - 80 to 84 years                                        356
# Female; Estimate; AGE - 80 to 84 years                                      400
# Total; Estimate; AGE - 85 years and over                                    306
# Male; Estimate; AGE - 85 years and over                                     356
# Female; Estimate; AGE - 85 years and over                                   400
# Total; Estimate; SUMMARY INDICATORS - Median age (years)                    506
# Male; Estimate; SUMMARY INDICATORS - Median age (years)                     814
# Female; Estimate; SUMMARY INDICATORS - Median age (years)                   844
# Total; Estimate; SUMMARY INDICATORS - Sex ratio (males per 100 females)     450
# Total; Estimate; SUMMARY INDICATORS - Age dependency ratio                  663
# Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio             1067
# Total; Estimate; SUMMARY INDICATORS - Child dependency ratio               1324
# Length: 65, dtype: int64

# %% [markdown]
# Since we have missing values in this dataset, we need to clean data first, either by removing and not considering rows with 0s or by filling them with mean for example.
#
# My original idea was to group zipcodes similar to each other, so groups will be 601-999, 1000-1999, 2000-2999, etc. I was assuming that zipcodes in one group will be close to each other on the map, therefore groups will represent different regions on the map. Assumption was such that regions close to each other should have similar values for the population statistics and therefore for missing values I could've considered mean value of the column but only for this region, not entire column, since data for different states varies a lot. I tried implementing this, but realized I was running out of time, so decided to choose a simpler option.
#
# Then I thought that I should just remove rows with 0s at all, but then realized that the number of rows in the dataset dropped to 20344 from 33120 which is too much. Here I am showing how I removed all rows with 0s and got that result.

# %%
df = census_data.replace(0, pd.np.nan).dropna(axis=0, how='any') 
df.describe()
# Out:
#                 ZIP  Total; Estimate; Total population  \
# count  20344.000000                       20344.000000
# mean   48659.329532                       14854.215444
# std    27390.509821                       15735.721435
# min      601.000000                         192.000000
# 25%    27443.750000                        2861.500000
# 50%    48847.500000                        8581.000000
# 75%    70754.250000                       22749.000000
# max    99929.000000                      115013.000000
#
#        Male; Estimate; Total population  Female; Estimate; Total population  \
# count                      20344.000000                         20344.00000
# mean                        7288.589265                          7565.62618
# std                         7695.089379                          8066.58956
# min                           96.000000                            94.00000
# 25%                         1420.750000                          1418.00000
# 50%                         4265.000000                          4339.00000
# 75%                        11131.500000                         11621.00000
# max                        59208.000000                         59173.00000
#
#        Total; Estimate; AGE - Under 5 years  \
# count                          20344.000000
# mean                               5.963749
# std                                1.943438
# min                                0.400000
# 25%                                4.700000
# 50%                                5.800000
# 75%                                7.100000
# max                               21.200000
#
#        Male; Estimate; AGE - Under 5 years  \
# count                          20344.00000
# mean                               6.17528
# std                                2.38580
# min                                0.10000
# 25%                                4.60000
# 50%                                6.10000
# 75%                                7.60000
# max                               23.10000
#
#        Female; Estimate; AGE - Under 5 years  \
# count                           20344.000000
# mean                                5.762338
# std                                 2.240221
# min                                 0.200000
# 25%                                 4.300000
# 50%                                 5.600000
# 75%                                 7.000000
# max                                25.600000
#
#        Total; Estimate; AGE - 5 to 9 years  \
# count                         20344.000000
# mean                              6.329060
# std                               1.873459
# min                               0.400000
# 25%                               5.200000
# 50%                               6.300000
# 75%                               7.400000
# max                              17.400000
#
#        Male; Estimate; AGE - 5 to 9 years  \
# count                        20344.000000
# mean                             6.536296
# std                              2.321699
# min                              0.100000
# 25%                              5.100000
# 50%                              6.500000
# 75%                              7.900000
# max                             24.000000
#
#        Female; Estimate; AGE - 5 to 9 years  \
# count                          20344.000000
# mean                               6.132712
# std                                2.211184
# min                                0.100000
# 25%                                4.700000
# 50%                                6.000000
# 75%                                7.400000
# max                               19.800000
#
#                                    ...                               \
# count                              ...
# mean                               ...
# std                                ...
# min                                ...
# 25%                                ...
# 50%                                ...
# 75%                                ...
# max                                ...
#
#        Total; Estimate; AGE - 85 years and over  \
# count                              20344.000000
# mean                                   2.107688
# std                                    1.300493
# min                                    0.100000
# 25%                                    1.200000
# 50%                                    1.800000
# 75%                                    2.700000
# max                                   18.800000
#
#        Male; Estimate; AGE - 85 years and over  \
# count                             20344.000000
# mean                                  1.489343
# std                                   1.125440
# min                                   0.100000
# 25%                                   0.700000
# 50%                                   1.200000
# 75%                                   1.900000
# max                                  18.400000
#
#        Female; Estimate; AGE - 85 years and over  \
# count                               20344.000000
# mean                                    2.712820
# std                                     1.774523
# min                                     0.100000
# 25%                                     1.500000
# 50%                                     2.400000
# 75%                                     3.500000
# max                                    20.700000
#
#        Total; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       20344.000000
# mean                                           40.512820
# std                                             6.256045
# min                                            19.400000
# 25%                                            36.400000
# 50%                                            40.600000
# 75%                                            44.300000
# max                                            73.600000
#
#        Male; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       20344.000000
# mean                                           39.394450
# std                                             6.458894
# min                                            16.900000
# 25%                                            35.100000
# 50%                                            39.300000
# 75%                                            43.400000
# max                                            72.800000
#
#        Female; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       20344.000000
# mean                                           41.575305
# std                                             6.456108
# min                                            17.900000
# 25%                                            37.400000
# 50%                                            41.700000
# 75%                                            45.600000
# max                                            74.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Sex ratio (males per 100 females)  \
# count                                       20344.000000
# mean                                           99.333071
# std                                            17.399348
# min                                            56.700000
# 25%                                            92.000000
# 50%                                            97.300000
# 75%                                           103.500000
# max                                           723.100000
#
#        Total; Estimate; SUMMARY INDICATORS - Age dependency ratio  \
# count                                       20344.000000
# mean                                           64.760352
# std                                            14.375782
# min                                             4.700000
# 25%                                            56.900000
# 50%                                            63.800000
# 75%                                            71.600000
# max                                           339.400000
#
#        Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio  \
# count                                       20344.000000
# mean                                           26.744745
# std                                            12.143282
# min                                             1.800000
# 25%                                            19.300000
# 50%                                            25.000000
# 75%                                            31.500000
# max                                           322.400000
#
#        Total; Estimate; SUMMARY INDICATORS - Child dependency ratio
# count                                       20344.000000
# mean                                           38.015592
# std                                             9.520615
# min                                             2.100000
# 25%                                            32.400000
# 50%                                            37.700000
# 75%                                            43.200000
# max                                           107.900000
#
# [8 rows x 65 columns]

# %%
df.shape
# Out:
# (20344, 65)

# %%
print(df.agg({'Total; Estimate; Total population':'sum'})) # if we ignore all rows with 0s, entire population is 
# 302 million instead of 318 million
# Out:
# Total; Estimate; Total population    302194159.0
# dtype: float64

# %%
# Idea that I haven't finished implementing, related to binning zipcodes into groups

# let's create a new column which is the string for the first two numbers in zipcode
# census_data['zipcode_region'] = census_data['ZIP'].astype(str).str.zfill(5).str.slice(0, 2)
# print(census_data['zipcode_region'])
# groupby_region = census_data.groupby('zipcode_region',as_index=False).agg({'':'sum')

# later, I decided to fill in missing values with the mean for entire column 
cols_not_considered = ['ZIP',
                      'Total; Estimate; SUMMARY INDICATORS - Median age (years)',
                      'Male; Estimate; SUMMARY INDICATORS - Median age (years)','Female; Estimate; SUMMARY INDICATORS - Median age (years)',
                      'Total; Estimate; SUMMARY INDICATORS - Age dependency ratio','Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio',
                      'Total; Estimate; SUMMARY INDICATORS - Child dependency ratio']
for col in census_data:
    if col not in cols_not_considered:
        mean_val = census_data[col].mean()
       
        # replace 0s with na
        census_data[col].replace(0, pd.np.nan,inplace=True)

        # fill those with mean val
        census_data[col].fillna(mean_val,inplace=True)
        
census_data.describe()
# Out:
#                 ZIP  Total; Estimate; Total population  \
# count  33120.000000                       33120.000000
# mean   49666.334209                        9681.908123
# std    27564.925769                       14059.607452
# min      601.000000                           1.000000
# 25%    26634.750000                         757.750000
# 50%    49739.000000                        2955.000000
# 75%    72123.500000                       13066.000000
# max    99929.000000                      115013.000000
#
#        Male; Estimate; Total population  Female; Estimate; Total population  \
# count                      33120.000000                        33120.000000
# mean                        4768.236725                         4934.631439
# std                         6876.427447                         7195.624105
# min                            1.000000                            1.000000
# 25%                          388.000000                          376.000000
# 50%                         1498.000000                         1484.000000
# 75%                         6448.000000                         6613.000000
# max                        59208.000000                        59173.000000
#
#        Total; Estimate; AGE - Under 5 years  \
# count                          33120.000000
# mean                               6.063958
# std                                2.887375
# min                                0.100000
# 25%                                4.500000
# 50%                                5.602965
# 75%                                7.100000
# max                               50.000000
#
#        Male; Estimate; AGE - Under 5 years  \
# count                         33120.000000
# mean                              6.423776
# std                               3.663272
# min                               0.100000
# 25%                               4.600000
# 50%                               5.750769
# 75%                               7.500000
# max                             100.000000
#
#        Female; Estimate; AGE - Under 5 years  \
# count                           33120.000000
# mean                                6.102947
# std                                 3.513608
# min                                 0.100000
# 25%                                 4.400000
# 50%                                 5.457210
# 75%                                 7.100000
# max                                87.100000
#
#        Total; Estimate; AGE - 5 to 9 years  \
# count                         33120.000000
# mean                              6.417886
# std                               2.838625
# min                               0.100000
# 25%                               5.000000
# 50%                               6.000000
# 75%                               7.500000
# max                              68.800000
#
#        Male; Estimate; AGE - 5 to 9 years  \
# count                        33120.000000
# mean                             6.740677
# std                              3.460954
# min                              0.100000
# 25%                              5.000000
# 50%                              6.074698
# 75%                              7.900000
# max                            100.000000
#
#        Female; Estimate; AGE - 5 to 9 years  \
# count                          33120.000000
# mean                               6.488414
# std                                3.581220
# min                                0.100000
# 25%                                4.800000
# 50%                                5.859795
# 75%                                7.500000
# max                              100.000000
#
#                                    ...                               \
# count                              ...
# mean                               ...
# std                                ...
# min                                ...
# 25%                                ...
# 50%                                ...
# 75%                                ...
# max                                ...
#
#        Total; Estimate; AGE - 85 years and over  \
# count                              33120.000000
# mean                                   2.298289
# std                                    2.540270
# min                                    0.100000
# 25%                                    1.200000
# 50%                                    2.026175
# 75%                                    2.600000
# max                                   96.400000
#
#        Male; Estimate; AGE - 85 years and over  \
# count                             33120.000000
# mean                                  1.787169
# std                                   2.573364
# min                                   0.100000
# 25%                                   0.900000
# 50%                                   1.449802
# 75%                                   1.800000
# max                                 100.000000
#
#        Female; Estimate; AGE - 85 years and over  \
# count                               33120.000000
# mean                                    3.024447
# std                                     3.316609
# min                                     0.100000
# 25%                                     1.600000
# 50%                                     2.580562
# 75%                                     3.400000
# max                                   100.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32614.000000
# mean                                           41.703983
# std                                             8.596534
# min                                             5.900000
# 25%                                            36.400000
# 50%                                            41.400000
# 75%                                            46.300000
# max                                            91.800000
#
#        Male; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32306.000000
# mean                                           40.683585
# std                                             8.936146
# min                                             2.900000
# 25%                                            35.100000
# 50%                                            40.200000
# 75%                                            45.600000
# max                                            87.100000
#
#        Female; Estimate; SUMMARY INDICATORS - Median age (years)  \
# count                                       32276.000000
# mean                                           42.451701
# std                                             8.843847
# min                                             1.900000
# 25%                                            37.200000
# 50%                                            42.400000
# 75%                                            47.400000
# max                                            94.300000
#
#        Total; Estimate; SUMMARY INDICATORS - Sex ratio (males per 100 females)  \
# count                                       33120.000000
# mean                                          110.123153
# std                                           282.762760
# min                                             1.900000
# 25%                                            91.500000
# 50%                                            98.500000
# 75%                                           108.300000
# max                                         31725.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Age dependency ratio  \
# count                                       32457.000000
# mean                                           67.838220
# std                                            56.738616
# min                                             0.000000
# 25%                                            55.300000
# 50%                                            63.900000
# 75%                                            74.200000
# max                                          6600.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Old-age dependency ratio  \
# count                                       32053.000000
# mean                                           31.081484
# std                                            55.975705
# min                                             0.000000
# 25%                                            19.000000
# 50%                                            25.500000
# 75%                                            34.000000
# max                                          6600.000000
#
#        Total; Estimate; SUMMARY INDICATORS - Child dependency ratio
# count                                       31796.000000
# mean                                           37.915804
# std                                            15.970163
# min                                             0.000000
# 25%                                            30.300000
# 50%                                            37.100000
# 75%                                            44.100000
# max                                           528.600000
#
# [8 rows x 65 columns]

# %% [markdown]
# Now, after I have filled in 0s with the mean values, I proceed to doing some analysis and finding trends.
#
# The most important question to ask from this dataset would probably be what is the difference between male and female population for different age groups and in general.
#
# Also, I would like to compare the total population in each age group. I will do this first.

# %%
# Total population is 317,729,255, i.e. around 318 million which makes sense 
print(census_data.agg({'Total; Estimate; Total population':'sum'}))
print(census_data.agg({'Male; Estimate; Total population':'sum'}))
print(census_data.agg({'Female; Estimate; Total population':'sum'}))

# We can see that in general there are slightly more females than males in the entire population of USA.
# Out:
# Total; Estimate; Total population    317729255
# dtype: int64
# Male; Estimate; Total population    156244560
# dtype: int64
# Female; Estimate; Total population    161484695
# dtype: int64

# %%
# draw bar chart for total population in each age category 
import numpy as np 
from matplotlib import rcParams

df = census_data
arr = np.zeros((19))
col_names = []
i = 0
for col in df:
    if ('Total' in col) & ('Male' not in col and 'Female' not in col) & ('SUMMARY' not in col):
        arr[i] = (df[col].sum())
        col_names.append(col[23:]) # remove some part of string, leaving only age
        i += 1

# first value is total population, ignore it 
# draw bar chart 
import matplotlib.pyplot as plt
y_pos = np.arange(len(arr[1:]))
rcParams['figure.figsize'] = 5.7,8.27
plt.barh(col_names[1:], arr[1:], align='center', alpha=0.5)
plt.xlabel('count of population')
plt.ylabel('age')
plt.show()

# %% [markdown]
# The graph above is showing total population in each age category in USA. It is very interesting to see that the largest age group in US is from the group of 50 to 59 years old, and obviously the smallest group is 85 years and older. There is also a peak in the number of people who are at the age of 15-19 years. Basically after that age group we see a drop in the number of people till the group of age 25-29 years old.
#
# Now I would like to create the same bar graph for these age groups but now separately for males and females to compare the population in each age category based on gender.

# %%
arr_male = np.zeros((18))
arr_female = np.zeros((18))
total_popul = arr[1:] # from previous experiment

i = 0
j = 0
df = census_data
for col in df:
    if ('Male' in col) & ('Total' not in col) & ('SUMMARY' not in col):
        l1 = df[col] * 0.01 
        val = l1.mean()
        arr_male[i] = (val * total_popul[i])
        i += 1
    if ('Female' in col) & ('Total' not in col) & ('SUMMARY' not in col):
        l2 = df[col] * 0.01 
        val = l2.mean()
        arr_female[j] = (val * total_popul[j])
        j += 1

# Now, let's draw our chart
y = range(len(arr_male))

rcParams['figure.figsize'] = 6.7,6.27
fig, axes = plt.subplots(ncols=2, sharey=True)
axes[0].set(title='count of males')
axes[1].set(title='count of females')
axes[0].set(yticks=y, yticklabels=col_names[1:])
for ax in axes.flat:
    ax.margins(0.03)
    ax.grid(True)

axes[0].barh(y, arr_male, align='center')
axes[1].barh(y, arr_female, align='center')
axes[0].invert_xaxis()

fig.tight_layout()
fig.subplots_adjust(wspace=0.03)
plt.show()

# %% [markdown]
# The graph above shows count of males and females in each age category. Looking at this graph we can see in which age categories there are more males or more females.
#
# For example, from this graph we can say that at the age 5-24 there are more males. But then I came up with better idea for this visualization, and decided to visualize the difference between male population and female population for each age group.

# %%
difference = arr_male-arr_female

y_pos = np.arange(len(difference))
rcParams['figure.figsize'] = 5.7,8.27
plt.barh(col_names[1:], difference, align='center', alpha=0.5)
plt.xlabel('difference between # of males and females')
plt.ylabel('age')
plt.show()

# %% [markdown]
# Now, this bar chart shows the difference between male and female population in each age group. The trend is very clear, that there are more males in the age groups starting from 0 years old and till 44 years old. Then later, the trend flips and in the rest of the groups there are more females.
